# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Clean_hospital_fee_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  age     sex   bmi  children smoker     region   charges  \
# 0           0   19  female  27.9         0    yes  southwest  16884.92
# 1           1   18    male  33.8         1     no  southeast   1725.55
# 2           2   28    male  33.0         3     no  southeast   4449.46
# 3           3   33    male  22.7         0     no  northwest  21984.47
# 4           4   32    male  28.9         0     no  northwest   3866.86
#
#   weight category
# 0     Over weight
# 1           obese
# 2           obese
# 3   normal weight
# 4     Over weight

# %%
df["region"].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df.describe()
df1 = df

# %%
df1.drop(["Unnamed: 0"],axis = 1)
# Out:
#       age     sex   bmi  children smoker     region   charges weight category
# 0      19  female  27.9         0    yes  southwest  16884.92     Over weight
# 1      18    male  33.8         1     no  southeast   1725.55           obese
# 2      28    male  33.0         3     no  southeast   4449.46           obese
# 3      33    male  22.7         0     no  northwest  21984.47   normal weight
# 4      32    male  28.9         0     no  northwest   3866.86     Over weight
# ...   ...     ...   ...       ...    ...        ...       ...             ...
# 1333   50    male  31.0         3     no  northwest  10600.55           obese
# 1334   18  female  31.9         0     no  northeast   2205.98           obese
# 1335   18  female  36.8         0     no  southeast   1629.83           obese
# 1336   21  female  25.8         0     no  southwest   2007.94     Over weight
# 1337   61  female  29.1         0    yes  northwest  29141.36     Over weight
#
# [1338 rows x 8 columns]

# %%
ax = df1.plot.hist(bins=12,alpha=0.5)

# %%
df1.charges.hist()

# %%
df1.age.hist()

# %%
df1.bmi.hist()

# %%
df2.rename(columns={"weight category": "weight_category"})
# Out:
#       Unnamed: 0  age     sex   bmi  children smoker     region   charges  \
# 0              0   19  female  27.9         0    yes  southwest  16884.92
# 1              1   18    male  33.8         1     no  southeast   1725.55
# 2              2   28    male  33.0         3     no  southeast   4449.46
# 3              3   33    male  22.7         0     no  northwest  21984.47
# 4              4   32    male  28.9         0     no  northwest   3866.86
# ...          ...  ...     ...   ...       ...    ...        ...       ...
# 1333        1333   50    male  31.0         3     no  northwest  10600.55
# 1334        1334   18  female  31.9         0     no  northeast   2205.98
# 1335        1335   18  female  36.8         0     no  southeast   1629.83
# 1336        1336   21  female  25.8         0     no  southwest   2007.94
# 1337        1337   61  female  29.1         0    yes  northwest  29141.36
#
#      weight_category
# 0        Over weight
# 1              obese
# ...

# %%
df1.plot(df1.weight_category.unique,df1.charges)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-7c118c0bcca7> in <module>
# ----> 1 df1.plot(df1.weight_category.unique,df1.charges)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'weight_category'

# %%
ax = df1.plot.bar(x='weight_category', y='charges', rot=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weight_category'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-714b3e2cac34> in <module>
# ...

# %%
df1.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-ce6a829fa934> in <module>
# ----> 1 df1.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-ea942bf769f0> in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df2 = df1.drop(["Unnamed: 0"],axis = 1)

# %%
df2.dtypes
# Out:
# age                  int64
# sex                 object
# bmi                float64
# children             int64
# smoker              object
# region              object
# charges            float64
# weight category     object
# dtype: object

# %%
df2.head()
# Out:
#    age     sex   bmi  children smoker     region   charges weight category
# 0   19  female  27.9         0    yes  southwest  16884.92     Over weight
# 1   18    male  33.8         1     no  southeast   1725.55           obese
# 2   28    male  33.0         3     no  southeast   4449.46           obese
# 3   33    male  22.7         0     no  northwest  21984.47   normal weight
# 4   32    male  28.9         0     no  northwest   3866.86     Over weight

# %%
df2.rename(columns={"weight category": "weight_category"})
# Out:
#       age     sex   bmi  children smoker     region   charges weight_category
# 0      19  female  27.9         0    yes  southwest  16884.92     Over weight
# 1      18    male  33.8         1     no  southeast   1725.55           obese
# 2      28    male  33.0         3     no  southeast   4449.46           obese
# 3      33    male  22.7         0     no  northwest  21984.47   normal weight
# 4      32    male  28.9         0     no  northwest   3866.86     Over weight
# ...   ...     ...   ...       ...    ...        ...       ...             ...
# 1333   50    male  31.0         3     no  northwest  10600.55           obese
# 1334   18  female  31.9         0     no  northeast   2205.98           obese
# 1335   18  female  36.8         0     no  southeast   1629.83           obese
# 1336   21  female  25.8         0     no  southwest   2007.94     Over weight
# 1337   61  female  29.1         0    yes  northwest  29141.36     Over weight
#
# [1338 rows x 8 columns]

# %%
ax = df2.plot.bar(x='weight category', y='charges',rot = 0)

# %%
df2["weight category"].value_counts()
# Out:
# obese            707
# Over weight      392
# normal weight    219
# Under weight      20
# Name: weight category, dtype: int64

# %%
df2.dtypes
# Out:
# age                  int64
# sex                 object
# bmi                float64
# children             int64
# smoker              object
# region              object
# charges            float64
# weight category     object
# dtype: object

# %%
df3 = df2.groupby('weight category').sum()

# %%
df3.head()
# Out:
#                    age      bmi  children      charges
# weight category
# Over weight      15264  10803.3       417   4333775.62
# Under weight       647    351.4        21    177044.02
# normal weight     8025   4939.2       245   2249504.12
# obese            28523  24933.6       782  10995501.25

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-653b92b11b2e> in <module>
# ----> 1 df3[1]
#
# ...

# %%
ax = df3.plot.bar(x=df3.index, y='charges',rot = 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-d2020a82c41b> in <module>
# ----> 1 ax = df3.plot.bar(x=df3.index, y='charges',rot = 0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1001             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1002         """
# -> 1003         return self(kind="bar", x=x, y=y, **kwargs)
#    1004
#    1005     def barh(self, x=None, y=None, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     810                 if is_integer(x) and not data.columns.holds_integer():
#     811                     x = data_cols[x]
# --> 812                 elif not isinstance(data[x], ABCSeries):
#     813                     raise ValueError("x must be a label or position")
# ...

# %%
df3.dtypes
# Out:
# age           int64
# bmi         float64
# children      int64
# charges     float64
# dtype: object

# %%
df3["weight_category"] = df3.index

# %%
df3.head()
# Out:
#                    age      bmi  children      charges weight_category
# weight category
# Over weight      15264  10803.3       417   4333775.62     Over weight
# Under weight       647    351.4        21    177044.02    Under weight
# normal weight     8025   4939.2       245   2249504.12   normal weight
# obese            28523  24933.6       782  10995501.25           obese

# %%
ax = df3.plot.bar(x='weight_category', y='charges',rot = 0)

# %%
ax1 = df2.plot.bar(x='smoker', y='charges',rot = 0)

# %%
df4 = df2.groupby('smoker').sum()

# %%
df4['smoker'] = df4.index

# %%
ax3 = df4.plot.bar(x='smoker', y='charges',rot = 0)

# %%
df5 = df2.groupby('sex').sum()

# %%
df5['sex'] = df5.index

# %%
ax3 = df5.plot.bar(x='sex', y='charges',rot = 0)

# %%
ax = sns.heatmap(df2, center=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-e280355def98> in <module>
# ----> 1 ax = sns.heatmap(df2, center=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     533     """
#     534     # Initialize the plotter object
# --> 535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
#     537                           yticklabels, mask)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     162
# ...

# %%
8+ 9
# Out:
# 17

# %%
import seaborn as sns
sns.set(style="darkgrid")

# %%
sns.lineplot(x="bmi", y="charges",
             hue="region",
             data=df2)

# %%
sns.set(rc={'figure.figsize':(11.7,5)})

# %%
sns.lineplot(x="bmi", y="charges",
             hue="region",
             data=df2)

# %%
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="bmi", y="charges",
                
                palette="ch:r=-.2,d=.3_r",
                
                sizes=(1, 8), linewidth=0,
                data=df2, ax=ax)

# %%
df6 = df2.groupby('region').sum()

# %%
df6['region'] = df6.index

# %%
df6.head()
# Out:
#              age      bmi  children     charges     region
# region
# northeast  12723   9452.2       339  4343668.61  northeast
# northwest  12739   9490.2       373  4035711.93  northwest
# southeast  14174  12141.2       382  5363689.78  southeast
# southwest  12823   9943.9       371  4012754.69  southwest

# %%
ax4 = df6.plot.bar(x='region', y='charges',rot = 0)
